# %% [markdown]
# # Visualizing results
#
# Here, we will show some typical examples of visualizations that are used often to show results in ML studies in materials science.
#
# We will use the open-source [`ML_figures` package](https://github.com/kaaiian/ML_figures) and the example data provided by the package to generate these figures.

# %%
# !git clone https://github.com/kaaiian/ML_figures.git
# Out:
# Cloning into 'ML_figures'...

# %%
import sys
sys.path.append('ML_figures')

from ML_figures.figures import act_pred, residual, residual_hist, loss_curve, element_prevalence

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
# Import the ML_figures package and the figure-plotting functions
from ML_figures.figures import act_pred, residual, residual_hist, loss_curve, element_prevalence

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# Install the ML_figures package
# %pip install git+https://github.com/kaaiian/ML_figures.git

# Import the ML_figures package and the figure-plotting functions
from ML_figures.figures import act_pred, residual, residual_hist, loss_curve, element_prevalence
# Out:
# Collecting git+https://github.com/kaaiian/ML_figures.git
#   Cloning https://github.com/kaaiian/ML_figures.git to c:\users\himanshu balhara\appdata\local\temp\pip-req-build-1hnqmllw
#   Resolved https://github.com/kaaiian/ML_figures.git to commit 48c07d5324208c6b7832f83f98b7cfe7672b1618
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/kaaiian/ML_figures.git 'C:\Users\Himanshu Balhara\AppData\Local\Temp\pip-req-build-1hnqmllw'
# ERROR: git+https://github.com/kaaiian/ML_figures.git does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %% [markdown]
# ## Predicted vs. actual value plots
#
# These plots, you have already seen before in the previous notebooks.

# %%
# Read in example act vs. pred data
df_act_pred = pd.read_csv(r'C:\Courses\MSEN655\HW_4\ML_figures\example_data\act_pred.csv')
y_act, y_pred = df_act_pred.iloc[:, 1], df_act_pred.iloc[:, 2]

act_pred(y_act, y_pred,
         save_dir='ML_figures/example_figures')

act_pred(y_act, y_pred,
         name='example_no_hist',
         x_hist=False, y_hist=False,
         save_dir='ML_figures/example_figures')

# %% [markdown]
# ## Residual error plots
#
# Residual error plots show how far your model's predictions deviate from the actual values.
# They are using the same data used in the predicted vs. actual plots; however, instead of plotting predicted vs. actual values, residual error plots plot (predicted - actual) vs. actual values.
#
# This lets you visually analyze your model's prediction error on a straight horizontal line.
#
# Alternatively, you can plot the residual errors on a histogram, and optionally with a kernel density estimation (kde).

# %%
residual(y_act, y_pred,
         save_dir='ML_figures/example_figures')

residual_hist(y_act, y_pred,
              save_dir='ML_figures/example_figures')

# %% [markdown]
# ## Loss curves
#
# Loss curves show the loss of a neural network model vs. epoch throughout the training process.
# It is typically evaluated using the training and validation dataset at the end of each epoch (or every $n$ epochs, where $n$ is a small number, if evaluating every epoch takes too many resources).
#
# Typically, loss curves plot the model performance (such as $r^2$ score) or loss (such as $\textrm{MAE}$) against epoch.

# %%
# Read in loss curve data
df_lc = pd.read_csv('ML_figures/example_data/training_progress.csv')
epoch = df_lc['epoch']
train_err, val_err = df_lc['mae_train'], df_lc['mae_val']

loss_curve(epoch, train_err, val_err,
           save_dir='ML_figures/example_figures')

# %% [markdown]
# ## Visualizing elemental prevalence
#
# Depending on your dataset, what you are studying, and how the compounds/constituent elements of the compounds in the dataset are distributed, it may be useful to visualize the elemental prevalence in your dataset.
#
# These figures let you visualize the relative amount of certain elements vs. other elements present in your dataset, and can help you in identifying dataset biases, imbalanced datasets, or other issues.

# %%
# Visualize element prevalence
formula = df_act_pred.iloc[:, 0]

element_prevalence(formula,
                   save_dir='ML_figures/example_figures',
                   log_scale=False)
element_prevalence(formula,
                   save_dir='ML_figures/example_figures',
                   name='example_log',
                   log_scale=True)

plt.rcParams.update({'font.size': 12})
element_prevalence(formula,
                   save_dir='ML_figures/example_figures',
                   ptable_fig=False,
                   log_scale=False)
element_prevalence(formula,
                   save_dir='ML_figures/example_figures',
                   name='example_log',
                   ptable_fig=False,
                   log_scale=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[34], line 4
#       1 # Visualize element prevalence
#       2 formula = df_act_pred.iloc[:, 0]
# ----> 4 element_prevalence(formula,
#       5                    save_dir='ML_figures/example_figures',
#       6                    log_scale=False)
#       7 element_prevalence(formula,
#       8                    save_dir='ML_figures/example_figures',
#       9                    name='example_log',
#      10                    log_scale=True)
#      12 plt.rcParams.update({'font.size': 12})
#
# File c:\Courses\MSEN655\HW_4\ML_figures\figures.py:265, in element_prevalence(formulae, name, save_dir, log_scale, ptable_fig)
#     260 def element_prevalence(formulae,
#     261                        name='example',
#     262                        save_dir=None,
#     263                        log_scale=False,
#     264                        ptable_fig=True):
# --> 265     ptable = pd.read_csv('element_properties/ptable.csv')
#     266     ptable.index = ptable['symbol'].values
#     267     elem_tracker = ptable['count']
#
# File c:\Software\Anaconda\envs\pytorch_env\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Software\Anaconda\envs\pytorch_env\lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Software\Anaconda\envs\pytorch_env\lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Software\Anaconda\envs\pytorch_env\lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Software\Anaconda\envs\pytorch_env\lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'element_properties/ptable.csv'
